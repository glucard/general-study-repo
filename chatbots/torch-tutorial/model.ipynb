# %%
# and put in a ``data/`` directory under the current directory.
#
# After that, let’s import some necessities.
#

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")
device
# Out:
# device(type='cuda')

# %%
corpus_name = "movie-corpus"
corpus = os.path.join("data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "utterances.jsonl"))
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'

# %%
# Splits each line of the file to create lines and conversations
def loadLinesAndConversations(fileName):
    lines = {}
    conversations = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            lineJson = json.loads(line)
            # Extract fields for line object
            lineObj = {}
            lineObj["lineID"] = lineJson["id"]
            lineObj["characterID"] = lineJson["speaker"]
            lineObj["text"] = lineJson["text"]
            lines[lineObj['lineID']] = lineObj

            # Extract fields for conversation object
            if lineJson["conversation_id"] not in conversations:
                convObj = {}
                convObj["conversationID"] = lineJson["conversation_id"]
                convObj["movieID"] = lineJson["meta"]["movie_id"]
                convObj["lines"] = [lineObj]
            else:
                convObj = conversations[lineJson["conversation_id"]]
                convObj["lines"].insert(0, lineObj)
            conversations[convObj["conversationID"]] = convObj

    return lines, conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations.values():
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict and conversations dict
lines = {}
conversations = {}
# Load lines and conversations
print("\nProcessing corpus into lines and conversations...")
lines, conversations = loadLinesAndConversations(os.path.join(corpus, "utterances.jsonl"))

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True if both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using the ``filterPair`` condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18082
#
# pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  11,  663,   92,   36,  103],
#         [ 111,   20,  132,   17,  208],
#         [ 359,  681,  319,    7,  135],
#         [  26,   14,   92,  103,   11],
#         [ 857, 1918,  132,   11,   10],
#         [  99,   14,  319, 1079,    2],
#         [  36,   14,    6,   14,    0],
#         [5076,   14,    2,    2,    0],
#         [  14,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([10,  9,  8,  8,  6])
# target_variable: tensor([[ 109,   11,   11,  128,   34],
#         [  24,  690,  111,  162,   34],
#         [6982,  228,  135,  146,   34],
#         [  87,   62,   49,   14,   34],
#         [  10,  809,   50,   14,   34],
#         [   2, 1131, 1008,   14,   34],
#         [   0,   14, 4088,    9,   14],
#         [   0,    2, 5653,   14,  781],
#         [   0,    0,   14,    2,   14],
#         [   0,    0,    2,    0,    2]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False, False,  True,  True,  True],
#         [False, False,  True, False,  True]])
# max_target_len: 10

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size parameters are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#``attn_model = 'general'``
#``attn_model = 'concat'``
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = True # None
checkpoint_iter = 8000

# %%
loadFilename = os.path.join(save_dir, model_name, corpus_name,
                    '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
                    '{}_checkpoint.tar'.format(checkpoint_iter))

# %%
# Load model if a ``loadFilename`` is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.00003
decoder_learning_ratio = 5.0
n_iteration = 16000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have CUDA, configure CUDA to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4001; Percent complete: 50.0%; Average loss: 2.5993
# Iteration: 4002; Percent complete: 50.0%; Average loss: 2.7554
# Iteration: 4003; Percent complete: 50.0%; Average loss: 2.5494
# Iteration: 4004; Percent complete: 50.0%; Average loss: 2.4600
# Iteration: 4005; Percent complete: 50.1%; Average loss: 2.7218
# Iteration: 4006; Percent complete: 50.1%; Average loss: 2.6007
# Iteration: 4007; Percent complete: 50.1%; Average loss: 2.7002
# Iteration: 4008; Percent complete: 50.1%; Average loss: 2.4747
# Iteration: 4009; Percent complete: 50.1%; Average loss: 2.7757
# Iteration: 4010; Percent complete: 50.1%; Average loss: 2.7568
# Iteration: 4011; Percent complete: 50.1%; Average loss: 2.3942
# Iteration: 4012; Percent complete: 50.1%; Average loss: 2.6634
# Iteration: 4013; Percent complete: 50.2%; Average loss: 2.6385
# Iteration: 4014; Percent complete: 50.2%; Average loss: 2.5010
# Iteration: 4015; Percent complete: 50.2%; Average loss: 2.5331
# Iteration: 4016; Percent complete: 50.2%; Average loss: 2.7893
# Iteration: 4017; Percent complete: 50.2%; Average loss: 2.5939
# Iteration: 4018; Percent complete: 50.2%; Average loss: 2.2974
# Iteration: 4019; Percent complete: 50.2%; Average loss: 2.6848
# Iteration: 4020; Percent complete: 50.2%; Average loss: 2.5902
# Iteration: 4021; Percent complete: 50.3%; Average loss: 2.8453
# Iteration: 4022; Percent complete: 50.3%; Average loss: 2.5963
# Iteration: 4023; Percent complete: 50.3%; Average loss: 2.8001
# Iteration: 4024; Percent complete: 50.3%; Average loss: 2.6331
# Iteration: 4025; Percent complete: 50.3%; Average loss: 2.6666
# Iteration: 4026; Percent complete: 50.3%; Average loss: 2.6847
# Iteration: 4027; Percent complete: 50.3%; Average loss: 2.4467
# Iteration: 4028; Percent complete: 50.3%; Average loss: 2.3870
# Iteration: 4029; Percent complete: 50.4%; Average loss: 2.7232
# Iteration: 4030; Percent complete: 50.4%; Average loss: 2.7180
# Iteration: 4031; Percent complete: 50.4%; Average loss: 2.5468
# Iteration: 4032; Percent complete: 50.4%; Average loss: 2.6393
# Iteration: 4033; Percent complete: 50.4%; Average loss: 2.6882
# Iteration: 4034; Percent complete: 50.4%; Average loss: 2.5834
# Iteration: 4035; Percent complete: 50.4%; Average loss: 2.7529
# Iteration: 4036; Percent complete: 50.4%; Average loss: 2.7994
# Iteration: 4037; Percent complete: 50.5%; Average loss: 3.0154
# Iteration: 4038; Percent complete: 50.5%; Average loss: 2.8081
# Iteration: 4039; Percent complete: 50.5%; Average loss: 2.5827
# Iteration: 4040; Percent complete: 50.5%; Average loss: 2.4756
# Iteration: 4041; Percent complete: 50.5%; Average loss: 2.5783
# Iteration: 4042; Percent complete: 50.5%; Average loss: 2.5366
# Iteration: 4043; Percent complete: 50.5%; Average loss: 2.5871
# Iteration: 4044; Percent complete: 50.5%; Average loss: 2.7507
# Iteration: 4045; Percent complete: 50.6%; Average loss: 2.6766
# Iteration: 4046; Percent complete: 50.6%; Average loss: 2.6032
# Iteration: 4047; Percent complete: 50.6%; Average loss: 2.4725
# Iteration: 4048; Percent complete: 50.6%; Average loss: 2.8017
# Iteration: 4049; Percent complete: 50.6%; Average loss: 2.7109
# Iteration: 4050; Percent complete: 50.6%; Average loss: 2.4308
# Iteration: 4051; Percent complete: 50.6%; Average loss: 2.5398
# Iteration: 4052; Percent complete: 50.6%; Average loss: 2.6957
# Iteration: 4053; Percent complete: 50.7%; Average loss: 2.6307
# Iteration: 4054; Percent complete: 50.7%; Average loss: 2.7144
# Iteration: 4055; Percent complete: 50.7%; Average loss: 2.3489
# Iteration: 4056; Percent complete: 50.7%; Average loss: 2.4288
# Iteration: 4057; Percent complete: 50.7%; Average loss: 2.7371
# Iteration: 4058; Percent complete: 50.7%; Average loss: 2.6692
# Iteration: 4059; Percent complete: 50.7%; Average loss: 2.4477
# Iteration: 4060; Percent complete: 50.7%; Average loss: 2.7283
# Iteration: 4061; Percent complete: 50.8%; Average loss: 2.8753
# Iteration: 4062; Percent complete: 50.8%; Average loss: 2.5355
# Iteration: 4063; Percent complete: 50.8%; Average loss: 2.6233
# Iteration: 4064; Percent complete: 50.8%; Average loss: 2.8770
# Iteration: 4065; Percent complete: 50.8%; Average loss: 2.4867
# Iteration: 4066; Percent complete: 50.8%; Average loss: 2.6995
# Iteration: 4067; Percent complete: 50.8%; Average loss: 2.8295
# Iteration: 4068; Percent complete: 50.8%; Average loss: 2.6630
# Iteration: 4069; Percent complete: 50.9%; Average loss: 2.5594
# Iteration: 4070; Percent complete: 50.9%; Average loss: 2.4602
# Iteration: 4071; Percent complete: 50.9%; Average loss: 2.7237
# Iteration: 4072; Percent complete: 50.9%; Average loss: 2.4697
# Iteration: 4073; Percent complete: 50.9%; Average loss: 2.7104
# Iteration: 4074; Percent complete: 50.9%; Average loss: 2.8424
# Iteration: 4075; Percent complete: 50.9%; Average loss: 2.5225
# Iteration: 4076; Percent complete: 50.9%; Average loss: 2.6699
# Iteration: 4077; Percent complete: 51.0%; Average loss: 2.4771
# Iteration: 4078; Percent complete: 51.0%; Average loss: 2.6203
# Iteration: 4079; Percent complete: 51.0%; Average loss: 2.3602
# Iteration: 4080; Percent complete: 51.0%; Average loss: 2.7061
# Iteration: 4081; Percent complete: 51.0%; Average loss: 2.7154
# Iteration: 4082; Percent complete: 51.0%; Average loss: 2.5337
# Iteration: 4083; Percent complete: 51.0%; Average loss: 2.4389
# Iteration: 4084; Percent complete: 51.0%; Average loss: 2.7827
# Iteration: 4085; Percent complete: 51.1%; Average loss: 2.5646
# Iteration: 4086; Percent complete: 51.1%; Average loss: 2.5860
# Iteration: 4087; Percent complete: 51.1%; Average loss: 2.7076
# Iteration: 4088; Percent complete: 51.1%; Average loss: 2.5945
# Iteration: 4089; Percent complete: 51.1%; Average loss: 2.6881
# Iteration: 4090; Percent complete: 51.1%; Average loss: 2.4327
# Iteration: 4091; Percent complete: 51.1%; Average loss: 2.4102
# Iteration: 4092; Percent complete: 51.1%; Average loss: 2.5685
# Iteration: 4093; Percent complete: 51.2%; Average loss: 2.6701
# Iteration: 4094; Percent complete: 51.2%; Average loss: 2.6678
# Iteration: 4095; Percent complete: 51.2%; Average loss: 2.6420
# Iteration: 4096; Percent complete: 51.2%; Average loss: 2.4227
# Iteration: 4097; Percent complete: 51.2%; Average loss: 2.5493
# Iteration: 4098; Percent complete: 51.2%; Average loss: 2.5342
# Iteration: 4099; Percent complete: 51.2%; Average loss: 2.6334
# Iteration: 4100; Percent complete: 51.2%; Average loss: 2.6190
# Iteration: 4101; Percent complete: 51.3%; Average loss: 2.5661
# Iteration: 4102; Percent complete: 51.3%; Average loss: 2.6505
# Iteration: 4103; Percent complete: 51.3%; Average loss: 2.5352
# Iteration: 4104; Percent complete: 51.3%; Average loss: 2.7382
# Iteration: 4105; Percent complete: 51.3%; Average loss: 2.5882
# Iteration: 4106; Percent complete: 51.3%; Average loss: 2.3293
# Iteration: 4107; Percent complete: 51.3%; Average loss: 2.7364
# Iteration: 4108; Percent complete: 51.3%; Average loss: 2.3965
# Iteration: 4109; Percent complete: 51.4%; Average loss: 2.7346
# Iteration: 4110; Percent complete: 51.4%; Average loss: 2.6329
# Iteration: 4111; Percent complete: 51.4%; Average loss: 2.5735
# Iteration: 4112; Percent complete: 51.4%; Average loss: 2.6035
# Iteration: 4113; Percent complete: 51.4%; Average loss: 2.5624
# Iteration: 4114; Percent complete: 51.4%; Average loss: 2.3866
# Iteration: 4115; Percent complete: 51.4%; Average loss: 2.6602
# Iteration: 4116; Percent complete: 51.4%; Average loss: 2.8815
# Iteration: 4117; Percent complete: 51.5%; Average loss: 2.6748
# Iteration: 4118; Percent complete: 51.5%; Average loss: 2.6159
# Iteration: 4119; Percent complete: 51.5%; Average loss: 2.6344
# Iteration: 4120; Percent complete: 51.5%; Average loss: 2.7428
# Iteration: 4121; Percent complete: 51.5%; Average loss: 2.3092
# Iteration: 4122; Percent complete: 51.5%; Average loss: 2.5130
# Iteration: 4123; Percent complete: 51.5%; Average loss: 2.6623
# Iteration: 4124; Percent complete: 51.5%; Average loss: 2.5064
# Iteration: 4125; Percent complete: 51.6%; Average loss: 2.5829
# Iteration: 4126; Percent complete: 51.6%; Average loss: 2.6602
# Iteration: 4127; Percent complete: 51.6%; Average loss: 2.3924
# Iteration: 4128; Percent complete: 51.6%; Average loss: 2.3592
# Iteration: 4129; Percent complete: 51.6%; Average loss: 2.5390
# Iteration: 4130; Percent complete: 51.6%; Average loss: 2.4889
# Iteration: 4131; Percent complete: 51.6%; Average loss: 2.6453
# Iteration: 4132; Percent complete: 51.6%; Average loss: 2.6645
# Iteration: 4133; Percent complete: 51.7%; Average loss: 2.5062
# Iteration: 4134; Percent complete: 51.7%; Average loss: 2.5813
# Iteration: 4135; Percent complete: 51.7%; Average loss: 2.5652
# Iteration: 4136; Percent complete: 51.7%; Average loss: 2.5087
# Iteration: 4137; Percent complete: 51.7%; Average loss: 2.4764
# Iteration: 4138; Percent complete: 51.7%; Average loss: 2.6428
# Iteration: 4139; Percent complete: 51.7%; Average loss: 2.5577
# Iteration: 4140; Percent complete: 51.7%; Average loss: 2.5891
# Iteration: 4141; Percent complete: 51.8%; Average loss: 2.6852
# Iteration: 4142; Percent complete: 51.8%; Average loss: 2.3831
# Iteration: 4143; Percent complete: 51.8%; Average loss: 2.5496
# Iteration: 4144; Percent complete: 51.8%; Average loss: 2.7311
# Iteration: 4145; Percent complete: 51.8%; Average loss: 2.3865
# Iteration: 4146; Percent complete: 51.8%; Average loss: 2.7435
# Iteration: 4147; Percent complete: 51.8%; Average loss: 2.6008
# Iteration: 4148; Percent complete: 51.8%; Average loss: 2.5451
# Iteration: 4149; Percent complete: 51.9%; Average loss: 2.3341
# Iteration: 4150; Percent complete: 51.9%; Average loss: 2.3843
# Iteration: 4151; Percent complete: 51.9%; Average loss: 2.5404
# Iteration: 4152; Percent complete: 51.9%; Average loss: 2.4007
# Iteration: 4153; Percent complete: 51.9%; Average loss: 2.7619
# Iteration: 4154; Percent complete: 51.9%; Average loss: 2.5117
# Iteration: 4155; Percent complete: 51.9%; Average loss: 2.5502
# Iteration: 4156; Percent complete: 51.9%; Average loss: 2.6532
# Iteration: 4157; Percent complete: 52.0%; Average loss: 2.5108
# Iteration: 4158; Percent complete: 52.0%; Average loss: 2.3956
# Iteration: 4159; Percent complete: 52.0%; Average loss: 2.4833
# Iteration: 4160; Percent complete: 52.0%; Average loss: 2.5394
# Iteration: 4161; Percent complete: 52.0%; Average loss: 2.5257
# Iteration: 4162; Percent complete: 52.0%; Average loss: 2.6091
# Iteration: 4163; Percent complete: 52.0%; Average loss: 2.6186
# Iteration: 4164; Percent complete: 52.0%; Average loss: 2.7373
# Iteration: 4165; Percent complete: 52.1%; Average loss: 2.4380
# Iteration: 4166; Percent complete: 52.1%; Average loss: 2.5267
# Iteration: 4167; Percent complete: 52.1%; Average loss: 2.5505
# Iteration: 4168; Percent complete: 52.1%; Average loss: 2.4762
# Iteration: 4169; Percent complete: 52.1%; Average loss: 2.7108
# Iteration: 4170; Percent complete: 52.1%; Average loss: 2.4589
# Iteration: 4171; Percent complete: 52.1%; Average loss: 2.4387
# Iteration: 4172; Percent complete: 52.1%; Average loss: 2.6418
# Iteration: 4173; Percent complete: 52.2%; Average loss: 2.5412
# Iteration: 4174; Percent complete: 52.2%; Average loss: 2.4384
# Iteration: 4175; Percent complete: 52.2%; Average loss: 2.4820
# Iteration: 4176; Percent complete: 52.2%; Average loss: 2.5949
# Iteration: 4177; Percent complete: 52.2%; Average loss: 2.6204
# Iteration: 4178; Percent complete: 52.2%; Average loss: 2.6301
# Iteration: 4179; Percent complete: 52.2%; Average loss: 2.3531
# Iteration: 4180; Percent complete: 52.2%; Average loss: 2.6636
# Iteration: 4181; Percent complete: 52.3%; Average loss: 2.7867
# Iteration: 4182; Percent complete: 52.3%; Average loss: 2.3374
# Iteration: 4183; Percent complete: 52.3%; Average loss: 2.6609
# Iteration: 4184; Percent complete: 52.3%; Average loss: 2.7091
# Iteration: 4185; Percent complete: 52.3%; Average loss: 2.5582
# Iteration: 4186; Percent complete: 52.3%; Average loss: 2.5575
# Iteration: 4187; Percent complete: 52.3%; Average loss: 2.4914
# Iteration: 4188; Percent complete: 52.3%; Average loss: 2.4533
# Iteration: 4189; Percent complete: 52.4%; Average loss: 2.4972
# Iteration: 4190; Percent complete: 52.4%; Average loss: 2.3081
# Iteration: 4191; Percent complete: 52.4%; Average loss: 2.5463
# Iteration: 4192; Percent complete: 52.4%; Average loss: 2.6959
# Iteration: 4193; Percent complete: 52.4%; Average loss: 2.6634
# Iteration: 4194; Percent complete: 52.4%; Average loss: 2.4592
# Iteration: 4195; Percent complete: 52.4%; Average loss: 2.7432
# Iteration: 4196; Percent complete: 52.4%; Average loss: 2.8361
# Iteration: 4197; Percent complete: 52.5%; Average loss: 2.5444
# Iteration: 4198; Percent complete: 52.5%; Average loss: 2.5346
# Iteration: 4199; Percent complete: 52.5%; Average loss: 2.5266
# Iteration: 4200; Percent complete: 52.5%; Average loss: 2.4446
# Iteration: 4201; Percent complete: 52.5%; Average loss: 2.8884
# Iteration: 4202; Percent complete: 52.5%; Average loss: 2.5392
# Iteration: 4203; Percent complete: 52.5%; Average loss: 2.7569
# Iteration: 4204; Percent complete: 52.5%; Average loss: 2.5064
# Iteration: 4205; Percent complete: 52.6%; Average loss: 2.5115
# Iteration: 4206; Percent complete: 52.6%; Average loss: 2.4787
# Iteration: 4207; Percent complete: 52.6%; Average loss: 2.5083
# Iteration: 4208; Percent complete: 52.6%; Average loss: 2.6499
# Iteration: 4209; Percent complete: 52.6%; Average loss: 2.5962
# Iteration: 4210; Percent complete: 52.6%; Average loss: 2.5151
# Iteration: 4211; Percent complete: 52.6%; Average loss: 2.5812
# Iteration: 4212; Percent complete: 52.6%; Average loss: 2.5609
# Iteration: 4213; Percent complete: 52.7%; Average loss: 2.5842
# Iteration: 4214; Percent complete: 52.7%; Average loss: 2.6058
# Iteration: 4215; Percent complete: 52.7%; Average loss: 2.4471
# Iteration: 4216; Percent complete: 52.7%; Average loss: 2.3167
# Iteration: 4217; Percent complete: 52.7%; Average loss: 2.5074
# Iteration: 4218; Percent complete: 52.7%; Average loss: 2.3045
# Iteration: 4219; Percent complete: 52.7%; Average loss: 2.5710
# Iteration: 4220; Percent complete: 52.8%; Average loss: 2.3698
# Iteration: 4221; Percent complete: 52.8%; Average loss: 2.3186
# Iteration: 4222; Percent complete: 52.8%; Average loss: 2.6038
# Iteration: 4223; Percent complete: 52.8%; Average loss: 2.5292
# Iteration: 4224; Percent complete: 52.8%; Average loss: 2.6846
# Iteration: 4225; Percent complete: 52.8%; Average loss: 2.6141
# Iteration: 4226; Percent complete: 52.8%; Average loss: 2.5478
# Iteration: 4227; Percent complete: 52.8%; Average loss: 2.9525
# Iteration: 4228; Percent complete: 52.8%; Average loss: 2.6264
# Iteration: 4229; Percent complete: 52.9%; Average loss: 2.6770
# Iteration: 4230; Percent complete: 52.9%; Average loss: 2.2577
# Iteration: 4231; Percent complete: 52.9%; Average loss: 2.3521
# Iteration: 4232; Percent complete: 52.9%; Average loss: 2.5758
# Iteration: 4233; Percent complete: 52.9%; Average loss: 2.5386
# Iteration: 4234; Percent complete: 52.9%; Average loss: 2.6483
# Iteration: 4235; Percent complete: 52.9%; Average loss: 2.4929
# Iteration: 4236; Percent complete: 52.9%; Average loss: 2.5405
# Iteration: 4237; Percent complete: 53.0%; Average loss: 2.6889
# Iteration: 4238; Percent complete: 53.0%; Average loss: 2.8058
# Iteration: 4239; Percent complete: 53.0%; Average loss: 2.5209
# Iteration: 4240; Percent complete: 53.0%; Average loss: 2.4745
# Iteration: 4241; Percent complete: 53.0%; Average loss: 2.6175
# Iteration: 4242; Percent complete: 53.0%; Average loss: 2.7976
# Iteration: 4243; Percent complete: 53.0%; Average loss: 2.4864
# Iteration: 4244; Percent complete: 53.0%; Average loss: 2.4017
# Iteration: 4245; Percent complete: 53.1%; Average loss: 2.5099
# Iteration: 4246; Percent complete: 53.1%; Average loss: 2.5284
# Iteration: 4247; Percent complete: 53.1%; Average loss: 2.4616
# Iteration: 4248; Percent complete: 53.1%; Average loss: 2.7147
# Iteration: 4249; Percent complete: 53.1%; Average loss: 2.7160
# Iteration: 4250; Percent complete: 53.1%; Average loss: 2.6360
# Iteration: 4251; Percent complete: 53.1%; Average loss: 2.3548
# Iteration: 4252; Percent complete: 53.1%; Average loss: 2.6602
# Iteration: 4253; Percent complete: 53.2%; Average loss: 2.4946
# Iteration: 4254; Percent complete: 53.2%; Average loss: 2.6107
# Iteration: 4255; Percent complete: 53.2%; Average loss: 2.7058
# Iteration: 4256; Percent complete: 53.2%; Average loss: 2.6187
# Iteration: 4257; Percent complete: 53.2%; Average loss: 2.4514
# Iteration: 4258; Percent complete: 53.2%; Average loss: 2.4285
# Iteration: 4259; Percent complete: 53.2%; Average loss: 2.4494
# Iteration: 4260; Percent complete: 53.2%; Average loss: 2.4835
# Iteration: 4261; Percent complete: 53.3%; Average loss: 2.3943
# Iteration: 4262; Percent complete: 53.3%; Average loss: 2.7215
# Iteration: 4263; Percent complete: 53.3%; Average loss: 2.4899
# Iteration: 4264; Percent complete: 53.3%; Average loss: 2.5483
# Iteration: 4265; Percent complete: 53.3%; Average loss: 2.5215
# Iteration: 4266; Percent complete: 53.3%; Average loss: 2.4236
# Iteration: 4267; Percent complete: 53.3%; Average loss: 2.4270
# Iteration: 4268; Percent complete: 53.3%; Average loss: 2.6279
# Iteration: 4269; Percent complete: 53.4%; Average loss: 2.6508
# Iteration: 4270; Percent complete: 53.4%; Average loss: 2.3436
# Iteration: 4271; Percent complete: 53.4%; Average loss: 2.3291
# Iteration: 4272; Percent complete: 53.4%; Average loss: 2.5808
# Iteration: 4273; Percent complete: 53.4%; Average loss: 2.4799
# Iteration: 4274; Percent complete: 53.4%; Average loss: 2.5483
# Iteration: 4275; Percent complete: 53.4%; Average loss: 2.4465
# Iteration: 4276; Percent complete: 53.4%; Average loss: 2.6105
# Iteration: 4277; Percent complete: 53.5%; Average loss: 2.4723
# Iteration: 4278; Percent complete: 53.5%; Average loss: 2.4697
# Iteration: 4279; Percent complete: 53.5%; Average loss: 2.4420
# Iteration: 4280; Percent complete: 53.5%; Average loss: 2.5485
# Iteration: 4281; Percent complete: 53.5%; Average loss: 2.3671
# Iteration: 4282; Percent complete: 53.5%; Average loss: 2.5108
# Iteration: 4283; Percent complete: 53.5%; Average loss: 2.5863
# Iteration: 4284; Percent complete: 53.5%; Average loss: 2.4023
# Iteration: 4285; Percent complete: 53.6%; Average loss: 2.5852
# Iteration: 4286; Percent complete: 53.6%; Average loss: 2.6434
# Iteration: 4287; Percent complete: 53.6%; Average loss: 2.3031
# Iteration: 4288; Percent complete: 53.6%; Average loss: 2.3903
# Iteration: 4289; Percent complete: 53.6%; Average loss: 2.5830
# Iteration: 4290; Percent complete: 53.6%; Average loss: 2.5228
# Iteration: 4291; Percent complete: 53.6%; Average loss: 2.4479
# Iteration: 4292; Percent complete: 53.6%; Average loss: 2.3268
# Iteration: 4293; Percent complete: 53.7%; Average loss: 2.6934
# Iteration: 4294; Percent complete: 53.7%; Average loss: 2.5233
# Iteration: 4295; Percent complete: 53.7%; Average loss: 2.4777
# Iteration: 4296; Percent complete: 53.7%; Average loss: 2.5193
# Iteration: 4297; Percent complete: 53.7%; Average loss: 2.7304
# Iteration: 4298; Percent complete: 53.7%; Average loss: 2.5908
# Iteration: 4299; Percent complete: 53.7%; Average loss: 2.4610
# Iteration: 4300; Percent complete: 53.8%; Average loss: 2.6286
# Iteration: 4301; Percent complete: 53.8%; Average loss: 2.6263
# Iteration: 4302; Percent complete: 53.8%; Average loss: 2.4168
# Iteration: 4303; Percent complete: 53.8%; Average loss: 2.5655
# Iteration: 4304; Percent complete: 53.8%; Average loss: 2.6088
# Iteration: 4305; Percent complete: 53.8%; Average loss: 2.6630
# Iteration: 4306; Percent complete: 53.8%; Average loss: 2.5986
# Iteration: 4307; Percent complete: 53.8%; Average loss: 2.4072
# Iteration: 4308; Percent complete: 53.8%; Average loss: 2.5769
# Iteration: 4309; Percent complete: 53.9%; Average loss: 2.5793
# Iteration: 4310; Percent complete: 53.9%; Average loss: 2.6026
# Iteration: 4311; Percent complete: 53.9%; Average loss: 2.7978
# Iteration: 4312; Percent complete: 53.9%; Average loss: 2.6132
# Iteration: 4313; Percent complete: 53.9%; Average loss: 2.6536
# Iteration: 4314; Percent complete: 53.9%; Average loss: 2.5293
# Iteration: 4315; Percent complete: 53.9%; Average loss: 2.5845
# Iteration: 4316; Percent complete: 53.9%; Average loss: 2.8208
# Iteration: 4317; Percent complete: 54.0%; Average loss: 2.5776
# Iteration: 4318; Percent complete: 54.0%; Average loss: 2.6644
# Iteration: 4319; Percent complete: 54.0%; Average loss: 2.4508
# Iteration: 4320; Percent complete: 54.0%; Average loss: 2.5066
# Iteration: 4321; Percent complete: 54.0%; Average loss: 2.6500
# Iteration: 4322; Percent complete: 54.0%; Average loss: 2.5048
# Iteration: 4323; Percent complete: 54.0%; Average loss: 2.5050
# Iteration: 4324; Percent complete: 54.0%; Average loss: 2.5343
# Iteration: 4325; Percent complete: 54.1%; Average loss: 2.6114
# Iteration: 4326; Percent complete: 54.1%; Average loss: 2.4838
# Iteration: 4327; Percent complete: 54.1%; Average loss: 2.5686
# Iteration: 4328; Percent complete: 54.1%; Average loss: 2.4841
# Iteration: 4329; Percent complete: 54.1%; Average loss: 2.6193
# Iteration: 4330; Percent complete: 54.1%; Average loss: 2.7153
# Iteration: 4331; Percent complete: 54.1%; Average loss: 2.5079
# Iteration: 4332; Percent complete: 54.1%; Average loss: 2.5464
# Iteration: 4333; Percent complete: 54.2%; Average loss: 2.2606
# Iteration: 4334; Percent complete: 54.2%; Average loss: 2.5888
# Iteration: 4335; Percent complete: 54.2%; Average loss: 2.4022
# Iteration: 4336; Percent complete: 54.2%; Average loss: 2.5977
# Iteration: 4337; Percent complete: 54.2%; Average loss: 2.3052
# Iteration: 4338; Percent complete: 54.2%; Average loss: 2.5118
# Iteration: 4339; Percent complete: 54.2%; Average loss: 2.4533
# Iteration: 4340; Percent complete: 54.2%; Average loss: 2.6677
# Iteration: 4341; Percent complete: 54.3%; Average loss: 2.4626
# Iteration: 4342; Percent complete: 54.3%; Average loss: 2.5368
# Iteration: 4343; Percent complete: 54.3%; Average loss: 2.4435
# Iteration: 4344; Percent complete: 54.3%; Average loss: 2.5231
# Iteration: 4345; Percent complete: 54.3%; Average loss: 2.6922
# Iteration: 4346; Percent complete: 54.3%; Average loss: 2.2621
# Iteration: 4347; Percent complete: 54.3%; Average loss: 2.4284
# Iteration: 4348; Percent complete: 54.4%; Average loss: 2.4214
# Iteration: 4349; Percent complete: 54.4%; Average loss: 2.6289
# Iteration: 4350; Percent complete: 54.4%; Average loss: 2.4293
# Iteration: 4351; Percent complete: 54.4%; Average loss: 2.5698
# Iteration: 4352; Percent complete: 54.4%; Average loss: 2.2131
# Iteration: 4353; Percent complete: 54.4%; Average loss: 2.4434
# Iteration: 4354; Percent complete: 54.4%; Average loss: 2.6229
# Iteration: 4355; Percent complete: 54.4%; Average loss: 2.6166
# Iteration: 4356; Percent complete: 54.4%; Average loss: 2.6400
# Iteration: 4357; Percent complete: 54.5%; Average loss: 2.3859
# Iteration: 4358; Percent complete: 54.5%; Average loss: 2.5949
# Iteration: 4359; Percent complete: 54.5%; Average loss: 2.5141
# Iteration: 4360; Percent complete: 54.5%; Average loss: 2.6846
# Iteration: 4361; Percent complete: 54.5%; Average loss: 2.4914
# Iteration: 4362; Percent complete: 54.5%; Average loss: 2.5370
# Iteration: 4363; Percent complete: 54.5%; Average loss: 2.6497
# Iteration: 4364; Percent complete: 54.5%; Average loss: 2.3907
# Iteration: 4365; Percent complete: 54.6%; Average loss: 2.7471
# Iteration: 4366; Percent complete: 54.6%; Average loss: 2.6733
# Iteration: 4367; Percent complete: 54.6%; Average loss: 2.3554
# Iteration: 4368; Percent complete: 54.6%; Average loss: 2.5548
# Iteration: 4369; Percent complete: 54.6%; Average loss: 2.5236
# Iteration: 4370; Percent complete: 54.6%; Average loss: 2.5250
# Iteration: 4371; Percent complete: 54.6%; Average loss: 2.6475
# Iteration: 4372; Percent complete: 54.6%; Average loss: 2.2704
# Iteration: 4373; Percent complete: 54.7%; Average loss: 2.4575
# Iteration: 4374; Percent complete: 54.7%; Average loss: 2.5269
# Iteration: 4375; Percent complete: 54.7%; Average loss: 2.2609
# Iteration: 4376; Percent complete: 54.7%; Average loss: 2.4886
# Iteration: 4377; Percent complete: 54.7%; Average loss: 2.5680
# Iteration: 4378; Percent complete: 54.7%; Average loss: 2.2635
# Iteration: 4379; Percent complete: 54.7%; Average loss: 2.6284
# Iteration: 4380; Percent complete: 54.8%; Average loss: 2.4602
# Iteration: 4381; Percent complete: 54.8%; Average loss: 2.4778
# Iteration: 4382; Percent complete: 54.8%; Average loss: 2.3344
# Iteration: 4383; Percent complete: 54.8%; Average loss: 2.5129
# Iteration: 4384; Percent complete: 54.8%; Average loss: 2.4799
# Iteration: 4385; Percent complete: 54.8%; Average loss: 2.8049
# Iteration: 4386; Percent complete: 54.8%; Average loss: 2.8512
# Iteration: 4387; Percent complete: 54.8%; Average loss: 2.6286
# Iteration: 4388; Percent complete: 54.9%; Average loss: 2.4919
# Iteration: 4389; Percent complete: 54.9%; Average loss: 2.4749
# Iteration: 4390; Percent complete: 54.9%; Average loss: 2.3887
# Iteration: 4391; Percent complete: 54.9%; Average loss: 2.4799
# Iteration: 4392; Percent complete: 54.9%; Average loss: 2.3823
# Iteration: 4393; Percent complete: 54.9%; Average loss: 2.6400
# Iteration: 4394; Percent complete: 54.9%; Average loss: 2.4201
# Iteration: 4395; Percent complete: 54.9%; Average loss: 2.4145
# Iteration: 4396; Percent complete: 54.9%; Average loss: 2.5176
# Iteration: 4397; Percent complete: 55.0%; Average loss: 2.4001
# Iteration: 4398; Percent complete: 55.0%; Average loss: 2.4642
# Iteration: 4399; Percent complete: 55.0%; Average loss: 2.5914
# Iteration: 4400; Percent complete: 55.0%; Average loss: 2.4567
# Iteration: 4401; Percent complete: 55.0%; Average loss: 2.3350
# Iteration: 4402; Percent complete: 55.0%; Average loss: 2.5367
# Iteration: 4403; Percent complete: 55.0%; Average loss: 2.3907
# Iteration: 4404; Percent complete: 55.0%; Average loss: 2.5460
# Iteration: 4405; Percent complete: 55.1%; Average loss: 2.6223
# Iteration: 4406; Percent complete: 55.1%; Average loss: 2.5728
# Iteration: 4407; Percent complete: 55.1%; Average loss: 2.5358
# Iteration: 4408; Percent complete: 55.1%; Average loss: 2.4755
# Iteration: 4409; Percent complete: 55.1%; Average loss: 2.8350
# Iteration: 4410; Percent complete: 55.1%; Average loss: 2.7373
# Iteration: 4411; Percent complete: 55.1%; Average loss: 2.5592
# Iteration: 4412; Percent complete: 55.1%; Average loss: 2.6282
# Iteration: 4413; Percent complete: 55.2%; Average loss: 2.3836
# Iteration: 4414; Percent complete: 55.2%; Average loss: 2.4126
# Iteration: 4415; Percent complete: 55.2%; Average loss: 2.6704
# Iteration: 4416; Percent complete: 55.2%; Average loss: 2.4611
# Iteration: 4417; Percent complete: 55.2%; Average loss: 2.7094
# Iteration: 4418; Percent complete: 55.2%; Average loss: 2.5257
# Iteration: 4419; Percent complete: 55.2%; Average loss: 2.4197
# Iteration: 4420; Percent complete: 55.2%; Average loss: 2.4468
# Iteration: 4421; Percent complete: 55.3%; Average loss: 2.5913
# Iteration: 4422; Percent complete: 55.3%; Average loss: 2.6537
# Iteration: 4423; Percent complete: 55.3%; Average loss: 2.4845
# Iteration: 4424; Percent complete: 55.3%; Average loss: 2.6098
# Iteration: 4425; Percent complete: 55.3%; Average loss: 2.6105
# Iteration: 4426; Percent complete: 55.3%; Average loss: 2.3717
# Iteration: 4427; Percent complete: 55.3%; Average loss: 2.3616
# Iteration: 4428; Percent complete: 55.4%; Average loss: 2.4771
# Iteration: 4429; Percent complete: 55.4%; Average loss: 2.6257
# Iteration: 4430; Percent complete: 55.4%; Average loss: 2.7361
# Iteration: 4431; Percent complete: 55.4%; Average loss: 2.4422
# Iteration: 4432; Percent complete: 55.4%; Average loss: 2.4858
# Iteration: 4433; Percent complete: 55.4%; Average loss: 2.4129
# Iteration: 4434; Percent complete: 55.4%; Average loss: 2.6331
# Iteration: 4435; Percent complete: 55.4%; Average loss: 2.6171
# Iteration: 4436; Percent complete: 55.5%; Average loss: 2.6864
# Iteration: 4437; Percent complete: 55.5%; Average loss: 2.5589
# Iteration: 4438; Percent complete: 55.5%; Average loss: 2.6242
# Iteration: 4439; Percent complete: 55.5%; Average loss: 2.5643
# Iteration: 4440; Percent complete: 55.5%; Average loss: 2.5162
# Iteration: 4441; Percent complete: 55.5%; Average loss: 2.6984
# Iteration: 4442; Percent complete: 55.5%; Average loss: 2.4545
# Iteration: 4443; Percent complete: 55.5%; Average loss: 2.6926
# Iteration: 4444; Percent complete: 55.5%; Average loss: 2.5371
# Iteration: 4445; Percent complete: 55.6%; Average loss: 2.4003
# Iteration: 4446; Percent complete: 55.6%; Average loss: 2.3868
# Iteration: 4447; Percent complete: 55.6%; Average loss: 2.4900
# Iteration: 4448; Percent complete: 55.6%; Average loss: 2.2605
# Iteration: 4449; Percent complete: 55.6%; Average loss: 2.4556
# Iteration: 4450; Percent complete: 55.6%; Average loss: 2.6415
# Iteration: 4451; Percent complete: 55.6%; Average loss: 2.3545
# Iteration: 4452; Percent complete: 55.6%; Average loss: 2.5120
# Iteration: 4453; Percent complete: 55.7%; Average loss: 2.5465
# Iteration: 4454; Percent complete: 55.7%; Average loss: 2.5641
# Iteration: 4455; Percent complete: 55.7%; Average loss: 2.5737
# Iteration: 4456; Percent complete: 55.7%; Average loss: 2.4559
# Iteration: 4457; Percent complete: 55.7%; Average loss: 2.3540
# Iteration: 4458; Percent complete: 55.7%; Average loss: 2.3845
# Iteration: 4459; Percent complete: 55.7%; Average loss: 2.5997
# Iteration: 4460; Percent complete: 55.8%; Average loss: 2.4993
# Iteration: 4461; Percent complete: 55.8%; Average loss: 2.3618
# Iteration: 4462; Percent complete: 55.8%; Average loss: 2.5237
# Iteration: 4463; Percent complete: 55.8%; Average loss: 2.5605
# Iteration: 4464; Percent complete: 55.8%; Average loss: 2.4164
# Iteration: 4465; Percent complete: 55.8%; Average loss: 2.4082
# Iteration: 4466; Percent complete: 55.8%; Average loss: 2.5003
# Iteration: 4467; Percent complete: 55.8%; Average loss: 2.4456
# Iteration: 4468; Percent complete: 55.9%; Average loss: 2.4796
# Iteration: 4469; Percent complete: 55.9%; Average loss: 2.4501
# Iteration: 4470; Percent complete: 55.9%; Average loss: 2.4123
# Iteration: 4471; Percent complete: 55.9%; Average loss: 2.4220
# Iteration: 4472; Percent complete: 55.9%; Average loss: 2.5582
# Iteration: 4473; Percent complete: 55.9%; Average loss: 2.5696
# Iteration: 4474; Percent complete: 55.9%; Average loss: 2.7960
# Iteration: 4475; Percent complete: 55.9%; Average loss: 2.3312
# Iteration: 4476; Percent complete: 56.0%; Average loss: 2.4400
# Iteration: 4477; Percent complete: 56.0%; Average loss: 2.7661
# Iteration: 4478; Percent complete: 56.0%; Average loss: 2.5306
# Iteration: 4479; Percent complete: 56.0%; Average loss: 2.4549
# Iteration: 4480; Percent complete: 56.0%; Average loss: 2.2420
# Iteration: 4481; Percent complete: 56.0%; Average loss: 2.3600
# Iteration: 4482; Percent complete: 56.0%; Average loss: 2.6199
# Iteration: 4483; Percent complete: 56.0%; Average loss: 2.7387
# Iteration: 4484; Percent complete: 56.0%; Average loss: 2.6405
# Iteration: 4485; Percent complete: 56.1%; Average loss: 2.5545
# Iteration: 4486; Percent complete: 56.1%; Average loss: 2.4663
# Iteration: 4487; Percent complete: 56.1%; Average loss: 2.6510
# Iteration: 4488; Percent complete: 56.1%; Average loss: 2.5456
# Iteration: 4489; Percent complete: 56.1%; Average loss: 2.3064
# Iteration: 4490; Percent complete: 56.1%; Average loss: 2.3081
# Iteration: 4491; Percent complete: 56.1%; Average loss: 2.4190
# Iteration: 4492; Percent complete: 56.1%; Average loss: 2.4411
# Iteration: 4493; Percent complete: 56.2%; Average loss: 2.2920
# Iteration: 4494; Percent complete: 56.2%; Average loss: 2.5905
# Iteration: 4495; Percent complete: 56.2%; Average loss: 2.4074
# Iteration: 4496; Percent complete: 56.2%; Average loss: 2.3507
# Iteration: 4497; Percent complete: 56.2%; Average loss: 2.4535
# Iteration: 4498; Percent complete: 56.2%; Average loss: 2.4688
# Iteration: 4499; Percent complete: 56.2%; Average loss: 2.4712
# Iteration: 4500; Percent complete: 56.2%; Average loss: 2.4792
# Iteration: 4501; Percent complete: 56.3%; Average loss: 2.6618
# Iteration: 4502; Percent complete: 56.3%; Average loss: 2.6345
# Iteration: 4503; Percent complete: 56.3%; Average loss: 2.5795
# Iteration: 4504; Percent complete: 56.3%; Average loss: 2.6357
# Iteration: 4505; Percent complete: 56.3%; Average loss: 2.5931
# Iteration: 4506; Percent complete: 56.3%; Average loss: 2.5305
# Iteration: 4507; Percent complete: 56.3%; Average loss: 2.4791
# Iteration: 4508; Percent complete: 56.4%; Average loss: 2.3421
# Iteration: 4509; Percent complete: 56.4%; Average loss: 2.4083
# Iteration: 4510; Percent complete: 56.4%; Average loss: 2.5909
# Iteration: 4511; Percent complete: 56.4%; Average loss: 2.3970
# Iteration: 4512; Percent complete: 56.4%; Average loss: 2.3423
# Iteration: 4513; Percent complete: 56.4%; Average loss: 2.3130
# Iteration: 4514; Percent complete: 56.4%; Average loss: 2.4466
# Iteration: 4515; Percent complete: 56.4%; Average loss: 2.7049
# Iteration: 4516; Percent complete: 56.5%; Average loss: 2.6110
# Iteration: 4517; Percent complete: 56.5%; Average loss: 2.4485
# Iteration: 4518; Percent complete: 56.5%; Average loss: 2.3711
# Iteration: 4519; Percent complete: 56.5%; Average loss: 2.5863
# Iteration: 4520; Percent complete: 56.5%; Average loss: 2.4707
# Iteration: 4521; Percent complete: 56.5%; Average loss: 2.4625
# Iteration: 4522; Percent complete: 56.5%; Average loss: 2.6171
# Iteration: 4523; Percent complete: 56.5%; Average loss: 2.4901
# Iteration: 4524; Percent complete: 56.5%; Average loss: 2.4107
# Iteration: 4525; Percent complete: 56.6%; Average loss: 2.6913
# Iteration: 4526; Percent complete: 56.6%; Average loss: 2.4592
# Iteration: 4527; Percent complete: 56.6%; Average loss: 2.3756
# Iteration: 4528; Percent complete: 56.6%; Average loss: 2.7115
# Iteration: 4529; Percent complete: 56.6%; Average loss: 2.5014
# Iteration: 4530; Percent complete: 56.6%; Average loss: 2.6660
# Iteration: 4531; Percent complete: 56.6%; Average loss: 2.4987
# Iteration: 4532; Percent complete: 56.6%; Average loss: 2.5262
# Iteration: 4533; Percent complete: 56.7%; Average loss: 2.3447
# Iteration: 4534; Percent complete: 56.7%; Average loss: 2.3965
# Iteration: 4535; Percent complete: 56.7%; Average loss: 2.5820
# Iteration: 4536; Percent complete: 56.7%; Average loss: 2.2375
# Iteration: 4537; Percent complete: 56.7%; Average loss: 2.7120
# Iteration: 4538; Percent complete: 56.7%; Average loss: 2.4598
# Iteration: 4539; Percent complete: 56.7%; Average loss: 2.4999
# Iteration: 4540; Percent complete: 56.8%; Average loss: 2.6171
# Iteration: 4541; Percent complete: 56.8%; Average loss: 2.3373
# Iteration: 4542; Percent complete: 56.8%; Average loss: 2.3261
# Iteration: 4543; Percent complete: 56.8%; Average loss: 2.2204
# Iteration: 4544; Percent complete: 56.8%; Average loss: 2.4202
# Iteration: 4545; Percent complete: 56.8%; Average loss: 2.3368
# Iteration: 4546; Percent complete: 56.8%; Average loss: 2.3224
# Iteration: 4547; Percent complete: 56.8%; Average loss: 2.5164
# Iteration: 4548; Percent complete: 56.9%; Average loss: 2.2714
# Iteration: 4549; Percent complete: 56.9%; Average loss: 2.4577
# Iteration: 4550; Percent complete: 56.9%; Average loss: 2.4763
# Iteration: 4551; Percent complete: 56.9%; Average loss: 2.4077
# Iteration: 4552; Percent complete: 56.9%; Average loss: 2.4000
# Iteration: 4553; Percent complete: 56.9%; Average loss: 2.5771
# Iteration: 4554; Percent complete: 56.9%; Average loss: 2.4598
# Iteration: 4555; Percent complete: 56.9%; Average loss: 2.3773
# Iteration: 4556; Percent complete: 57.0%; Average loss: 2.5459
# Iteration: 4557; Percent complete: 57.0%; Average loss: 2.3675
# Iteration: 4558; Percent complete: 57.0%; Average loss: 2.2680
# Iteration: 4559; Percent complete: 57.0%; Average loss: 2.5208
# Iteration: 4560; Percent complete: 57.0%; Average loss: 2.5733
# Iteration: 4561; Percent complete: 57.0%; Average loss: 2.5368
# Iteration: 4562; Percent complete: 57.0%; Average loss: 2.4509
# Iteration: 4563; Percent complete: 57.0%; Average loss: 2.4576
# Iteration: 4564; Percent complete: 57.0%; Average loss: 2.5976
# Iteration: 4565; Percent complete: 57.1%; Average loss: 2.2380
# Iteration: 4566; Percent complete: 57.1%; Average loss: 2.5035
# Iteration: 4567; Percent complete: 57.1%; Average loss: 2.5284
# Iteration: 4568; Percent complete: 57.1%; Average loss: 2.4053
# Iteration: 4569; Percent complete: 57.1%; Average loss: 2.5004
# Iteration: 4570; Percent complete: 57.1%; Average loss: 2.5240
# Iteration: 4571; Percent complete: 57.1%; Average loss: 2.4975
# Iteration: 4572; Percent complete: 57.1%; Average loss: 2.5957
# Iteration: 4573; Percent complete: 57.2%; Average loss: 2.2637
# Iteration: 4574; Percent complete: 57.2%; Average loss: 2.5190
# Iteration: 4575; Percent complete: 57.2%; Average loss: 2.5639
# Iteration: 4576; Percent complete: 57.2%; Average loss: 2.2852
# Iteration: 4577; Percent complete: 57.2%; Average loss: 2.4035
# Iteration: 4578; Percent complete: 57.2%; Average loss: 2.4551
# Iteration: 4579; Percent complete: 57.2%; Average loss: 2.5868
# Iteration: 4580; Percent complete: 57.2%; Average loss: 2.3790
# Iteration: 4581; Percent complete: 57.3%; Average loss: 2.5893
# Iteration: 4582; Percent complete: 57.3%; Average loss: 2.6346
# Iteration: 4583; Percent complete: 57.3%; Average loss: 2.4572
# Iteration: 4584; Percent complete: 57.3%; Average loss: 2.5724
# Iteration: 4585; Percent complete: 57.3%; Average loss: 2.3616
# Iteration: 4586; Percent complete: 57.3%; Average loss: 2.4423
# Iteration: 4587; Percent complete: 57.3%; Average loss: 2.4277
# Iteration: 4588; Percent complete: 57.4%; Average loss: 2.3310
# Iteration: 4589; Percent complete: 57.4%; Average loss: 2.3971
# Iteration: 4590; Percent complete: 57.4%; Average loss: 2.4101
# Iteration: 4591; Percent complete: 57.4%; Average loss: 2.5425
# Iteration: 4592; Percent complete: 57.4%; Average loss: 2.5414
# Iteration: 4593; Percent complete: 57.4%; Average loss: 2.6144
# Iteration: 4594; Percent complete: 57.4%; Average loss: 2.4627
# Iteration: 4595; Percent complete: 57.4%; Average loss: 2.7631
# Iteration: 4596; Percent complete: 57.5%; Average loss: 2.4817
# Iteration: 4597; Percent complete: 57.5%; Average loss: 2.4418
# Iteration: 4598; Percent complete: 57.5%; Average loss: 2.5032
# Iteration: 4599; Percent complete: 57.5%; Average loss: 2.6164
# Iteration: 4600; Percent complete: 57.5%; Average loss: 2.3610
# Iteration: 4601; Percent complete: 57.5%; Average loss: 2.3274
# Iteration: 4602; Percent complete: 57.5%; Average loss: 2.4829
# Iteration: 4603; Percent complete: 57.5%; Average loss: 2.5141
# Iteration: 4604; Percent complete: 57.6%; Average loss: 2.4882
# Iteration: 4605; Percent complete: 57.6%; Average loss: 2.4179
# Iteration: 4606; Percent complete: 57.6%; Average loss: 2.5229
# Iteration: 4607; Percent complete: 57.6%; Average loss: 2.4381
# Iteration: 4608; Percent complete: 57.6%; Average loss: 2.7201
# Iteration: 4609; Percent complete: 57.6%; Average loss: 2.6160
# Iteration: 4610; Percent complete: 57.6%; Average loss: 2.4350
# Iteration: 4611; Percent complete: 57.6%; Average loss: 2.4192
# Iteration: 4612; Percent complete: 57.6%; Average loss: 2.6115
# Iteration: 4613; Percent complete: 57.7%; Average loss: 2.4824
# Iteration: 4614; Percent complete: 57.7%; Average loss: 2.4919
# Iteration: 4615; Percent complete: 57.7%; Average loss: 2.7690
# Iteration: 4616; Percent complete: 57.7%; Average loss: 2.4499
# Iteration: 4617; Percent complete: 57.7%; Average loss: 2.2687
# Iteration: 4618; Percent complete: 57.7%; Average loss: 2.4285
# Iteration: 4619; Percent complete: 57.7%; Average loss: 2.2612
# Iteration: 4620; Percent complete: 57.8%; Average loss: 2.5404
# Iteration: 4621; Percent complete: 57.8%; Average loss: 2.4364
# Iteration: 4622; Percent complete: 57.8%; Average loss: 2.4566
# Iteration: 4623; Percent complete: 57.8%; Average loss: 2.3979
# Iteration: 4624; Percent complete: 57.8%; Average loss: 2.3918
# Iteration: 4625; Percent complete: 57.8%; Average loss: 2.3452
# Iteration: 4626; Percent complete: 57.8%; Average loss: 2.6020
# Iteration: 4627; Percent complete: 57.8%; Average loss: 2.5914
# Iteration: 4628; Percent complete: 57.9%; Average loss: 2.5188
# Iteration: 4629; Percent complete: 57.9%; Average loss: 2.3013
# Iteration: 4630; Percent complete: 57.9%; Average loss: 2.4620
# Iteration: 4631; Percent complete: 57.9%; Average loss: 2.5357
# Iteration: 4632; Percent complete: 57.9%; Average loss: 2.6435
# Iteration: 4633; Percent complete: 57.9%; Average loss: 2.3800
# Iteration: 4634; Percent complete: 57.9%; Average loss: 2.4980
# Iteration: 4635; Percent complete: 57.9%; Average loss: 2.2765
# Iteration: 4636; Percent complete: 58.0%; Average loss: 2.5807
# Iteration: 4637; Percent complete: 58.0%; Average loss: 2.4816
# Iteration: 4638; Percent complete: 58.0%; Average loss: 2.2653
# Iteration: 4639; Percent complete: 58.0%; Average loss: 2.3952
# Iteration: 4640; Percent complete: 58.0%; Average loss: 2.1852
# Iteration: 4641; Percent complete: 58.0%; Average loss: 2.5035
# Iteration: 4642; Percent complete: 58.0%; Average loss: 2.3975
# Iteration: 4643; Percent complete: 58.0%; Average loss: 2.4829
# Iteration: 4644; Percent complete: 58.1%; Average loss: 2.6028
# Iteration: 4645; Percent complete: 58.1%; Average loss: 2.3249
# Iteration: 4646; Percent complete: 58.1%; Average loss: 2.4211
# Iteration: 4647; Percent complete: 58.1%; Average loss: 2.5100
# Iteration: 4648; Percent complete: 58.1%; Average loss: 2.3546
# Iteration: 4649; Percent complete: 58.1%; Average loss: 2.4783
# Iteration: 4650; Percent complete: 58.1%; Average loss: 2.2105
# Iteration: 4651; Percent complete: 58.1%; Average loss: 2.5057
# Iteration: 4652; Percent complete: 58.1%; Average loss: 2.5543
# Iteration: 4653; Percent complete: 58.2%; Average loss: 2.5539
# Iteration: 4654; Percent complete: 58.2%; Average loss: 2.4315
# Iteration: 4655; Percent complete: 58.2%; Average loss: 2.2826
# Iteration: 4656; Percent complete: 58.2%; Average loss: 2.3947
# Iteration: 4657; Percent complete: 58.2%; Average loss: 2.1682
# Iteration: 4658; Percent complete: 58.2%; Average loss: 2.3095
# Iteration: 4659; Percent complete: 58.2%; Average loss: 2.1871
# Iteration: 4660; Percent complete: 58.2%; Average loss: 2.4138
# Iteration: 4661; Percent complete: 58.3%; Average loss: 2.5437
# Iteration: 4662; Percent complete: 58.3%; Average loss: 2.3927
# Iteration: 4663; Percent complete: 58.3%; Average loss: 2.1969
# Iteration: 4664; Percent complete: 58.3%; Average loss: 2.4181
# Iteration: 4665; Percent complete: 58.3%; Average loss: 2.3911
# Iteration: 4666; Percent complete: 58.3%; Average loss: 2.3831
# Iteration: 4667; Percent complete: 58.3%; Average loss: 2.2913
# Iteration: 4668; Percent complete: 58.4%; Average loss: 2.6476
# Iteration: 4669; Percent complete: 58.4%; Average loss: 2.6076
# Iteration: 4670; Percent complete: 58.4%; Average loss: 2.4994
# Iteration: 4671; Percent complete: 58.4%; Average loss: 2.6672
# Iteration: 4672; Percent complete: 58.4%; Average loss: 2.4669
# Iteration: 4673; Percent complete: 58.4%; Average loss: 2.7364
# Iteration: 4674; Percent complete: 58.4%; Average loss: 2.4456
# Iteration: 4675; Percent complete: 58.4%; Average loss: 2.3875
# Iteration: 4676; Percent complete: 58.5%; Average loss: 2.5577
# Iteration: 4677; Percent complete: 58.5%; Average loss: 2.5476
# Iteration: 4678; Percent complete: 58.5%; Average loss: 2.5250
# Iteration: 4679; Percent complete: 58.5%; Average loss: 2.4609
# Iteration: 4680; Percent complete: 58.5%; Average loss: 2.2713
# Iteration: 4681; Percent complete: 58.5%; Average loss: 2.4476
# Iteration: 4682; Percent complete: 58.5%; Average loss: 2.6109
# Iteration: 4683; Percent complete: 58.5%; Average loss: 2.3474
# Iteration: 4684; Percent complete: 58.6%; Average loss: 2.3899
# Iteration: 4685; Percent complete: 58.6%; Average loss: 2.5506
# Iteration: 4686; Percent complete: 58.6%; Average loss: 2.6478
# Iteration: 4687; Percent complete: 58.6%; Average loss: 2.2296
# Iteration: 4688; Percent complete: 58.6%; Average loss: 2.4409
# Iteration: 4689; Percent complete: 58.6%; Average loss: 2.4154
# Iteration: 4690; Percent complete: 58.6%; Average loss: 2.3222
# Iteration: 4691; Percent complete: 58.6%; Average loss: 2.3082
# Iteration: 4692; Percent complete: 58.7%; Average loss: 2.3921
# Iteration: 4693; Percent complete: 58.7%; Average loss: 2.3953
# Iteration: 4694; Percent complete: 58.7%; Average loss: 2.2351
# Iteration: 4695; Percent complete: 58.7%; Average loss: 2.6043
# Iteration: 4696; Percent complete: 58.7%; Average loss: 2.5486
# Iteration: 4697; Percent complete: 58.7%; Average loss: 2.5598
# Iteration: 4698; Percent complete: 58.7%; Average loss: 2.6799
# Iteration: 4699; Percent complete: 58.7%; Average loss: 2.4179
# Iteration: 4700; Percent complete: 58.8%; Average loss: 2.3716
# Iteration: 4701; Percent complete: 58.8%; Average loss: 2.4193
# Iteration: 4702; Percent complete: 58.8%; Average loss: 2.2625
# Iteration: 4703; Percent complete: 58.8%; Average loss: 2.3132
# Iteration: 4704; Percent complete: 58.8%; Average loss: 2.5303
# Iteration: 4705; Percent complete: 58.8%; Average loss: 2.4174
# Iteration: 4706; Percent complete: 58.8%; Average loss: 2.3769
# Iteration: 4707; Percent complete: 58.8%; Average loss: 2.4588
# Iteration: 4708; Percent complete: 58.9%; Average loss: 2.5610
# Iteration: 4709; Percent complete: 58.9%; Average loss: 2.5570
# Iteration: 4710; Percent complete: 58.9%; Average loss: 2.3096
# Iteration: 4711; Percent complete: 58.9%; Average loss: 2.6143
# Iteration: 4712; Percent complete: 58.9%; Average loss: 2.2656
# Iteration: 4713; Percent complete: 58.9%; Average loss: 2.6052
# Iteration: 4714; Percent complete: 58.9%; Average loss: 2.2898
# Iteration: 4715; Percent complete: 58.9%; Average loss: 2.3458
# Iteration: 4716; Percent complete: 59.0%; Average loss: 2.5511
# Iteration: 4717; Percent complete: 59.0%; Average loss: 2.3479
# Iteration: 4718; Percent complete: 59.0%; Average loss: 2.4786
# Iteration: 4719; Percent complete: 59.0%; Average loss: 2.2445
# Iteration: 4720; Percent complete: 59.0%; Average loss: 2.3316
# Iteration: 4721; Percent complete: 59.0%; Average loss: 2.4848
# Iteration: 4722; Percent complete: 59.0%; Average loss: 2.3879
# Iteration: 4723; Percent complete: 59.0%; Average loss: 2.4967
# Iteration: 4724; Percent complete: 59.1%; Average loss: 2.1828
# Iteration: 4725; Percent complete: 59.1%; Average loss: 2.4751
# Iteration: 4726; Percent complete: 59.1%; Average loss: 2.3703
# Iteration: 4727; Percent complete: 59.1%; Average loss: 2.3994
# Iteration: 4728; Percent complete: 59.1%; Average loss: 2.3442
# Iteration: 4729; Percent complete: 59.1%; Average loss: 2.6357
# Iteration: 4730; Percent complete: 59.1%; Average loss: 2.2479
# Iteration: 4731; Percent complete: 59.1%; Average loss: 2.4656
# Iteration: 4732; Percent complete: 59.2%; Average loss: 2.3852
# Iteration: 4733; Percent complete: 59.2%; Average loss: 2.3017
# Iteration: 4734; Percent complete: 59.2%; Average loss: 2.3586
# Iteration: 4735; Percent complete: 59.2%; Average loss: 2.3814
# Iteration: 4736; Percent complete: 59.2%; Average loss: 2.6091
# Iteration: 4737; Percent complete: 59.2%; Average loss: 2.4489
# Iteration: 4738; Percent complete: 59.2%; Average loss: 2.4333
# Iteration: 4739; Percent complete: 59.2%; Average loss: 2.4413
# Iteration: 4740; Percent complete: 59.2%; Average loss: 2.3105
# Iteration: 4741; Percent complete: 59.3%; Average loss: 2.2923
# Iteration: 4742; Percent complete: 59.3%; Average loss: 2.4425
# Iteration: 4743; Percent complete: 59.3%; Average loss: 2.2620
# Iteration: 4744; Percent complete: 59.3%; Average loss: 2.3828
# Iteration: 4745; Percent complete: 59.3%; Average loss: 2.4046
# Iteration: 4746; Percent complete: 59.3%; Average loss: 2.3780
# Iteration: 4747; Percent complete: 59.3%; Average loss: 2.3524
# Iteration: 4748; Percent complete: 59.4%; Average loss: 2.3990
# Iteration: 4749; Percent complete: 59.4%; Average loss: 2.4193
# Iteration: 4750; Percent complete: 59.4%; Average loss: 2.2654
# Iteration: 4751; Percent complete: 59.4%; Average loss: 2.6132
# Iteration: 4752; Percent complete: 59.4%; Average loss: 2.2067
# Iteration: 4753; Percent complete: 59.4%; Average loss: 2.4263
# Iteration: 4754; Percent complete: 59.4%; Average loss: 2.4980
# Iteration: 4755; Percent complete: 59.4%; Average loss: 2.2781
# Iteration: 4756; Percent complete: 59.5%; Average loss: 2.3412
# Iteration: 4757; Percent complete: 59.5%; Average loss: 2.3367
# Iteration: 4758; Percent complete: 59.5%; Average loss: 2.3453
# Iteration: 4759; Percent complete: 59.5%; Average loss: 2.3836
# Iteration: 4760; Percent complete: 59.5%; Average loss: 2.5900
# ...
# Iteration: 7748; Percent complete: 96.9%; Average loss: 1.9506
# Iteration: 7749; Percent complete: 96.9%; Average loss: 1.5860
# Iteration: 7750; Percent complete: 96.9%; Average loss: 1.7056
# Iteration: 7751; Percent complete: 96.9%; Average loss: 1.7068
# Iteration: 7752; Percent complete: 96.9%; Average loss: 1.6746
# Iteration: 7753; Percent complete: 96.9%; Average loss: 1.7568
# Iteration: 7754; Percent complete: 96.9%; Average loss: 1.7849
# Iteration: 7755; Percent complete: 96.9%; Average loss: 1.7904
# Iteration: 7756; Percent complete: 97.0%; Average loss: 1.6483
# Iteration: 7757; Percent complete: 97.0%; Average loss: 1.7288
# Iteration: 7758; Percent complete: 97.0%; Average loss: 1.8026
# Iteration: 7759; Percent complete: 97.0%; Average loss: 1.7313
# Iteration: 7760; Percent complete: 97.0%; Average loss: 1.6375
# Iteration: 7761; Percent complete: 97.0%; Average loss: 1.6872
# Iteration: 7762; Percent complete: 97.0%; Average loss: 1.5027
# Iteration: 7763; Percent complete: 97.0%; Average loss: 1.8462
# Iteration: 7764; Percent complete: 97.0%; Average loss: 1.6985
# Iteration: 7765; Percent complete: 97.1%; Average loss: 1.5539
# Iteration: 7766; Percent complete: 97.1%; Average loss: 1.8006
# Iteration: 7767; Percent complete: 97.1%; Average loss: 1.6344
# Iteration: 7768; Percent complete: 97.1%; Average loss: 1.8828
# Iteration: 7769; Percent complete: 97.1%; Average loss: 1.7356
# Iteration: 7770; Percent complete: 97.1%; Average loss: 1.8649
# Iteration: 7771; Percent complete: 97.1%; Average loss: 1.8152
# Iteration: 7772; Percent complete: 97.2%; Average loss: 1.7545
# Iteration: 7773; Percent complete: 97.2%; Average loss: 1.6574
# Iteration: 7774; Percent complete: 97.2%; Average loss: 1.7824
# Iteration: 7775; Percent complete: 97.2%; Average loss: 1.7627
# Iteration: 7776; Percent complete: 97.2%; Average loss: 1.7175
# Iteration: 7777; Percent complete: 97.2%; Average loss: 1.6059
# Iteration: 7778; Percent complete: 97.2%; Average loss: 1.5469
# Iteration: 7779; Percent complete: 97.2%; Average loss: 1.7937
# Iteration: 7780; Percent complete: 97.2%; Average loss: 1.7536
# Iteration: 7781; Percent complete: 97.3%; Average loss: 1.6766
# Iteration: 7782; Percent complete: 97.3%; Average loss: 1.6215
# Iteration: 7783; Percent complete: 97.3%; Average loss: 1.8642
# Iteration: 7784; Percent complete: 97.3%; Average loss: 1.7011
# Iteration: 7785; Percent complete: 97.3%; Average loss: 1.9435
# Iteration: 7786; Percent complete: 97.3%; Average loss: 1.7715
# Iteration: 7787; Percent complete: 97.3%; Average loss: 1.6419
# Iteration: 7788; Percent complete: 97.4%; Average loss: 1.6030
# Iteration: 7789; Percent complete: 97.4%; Average loss: 1.7291
# Iteration: 7790; Percent complete: 97.4%; Average loss: 1.9168
# Iteration: 7791; Percent complete: 97.4%; Average loss: 1.7175
# Iteration: 7792; Percent complete: 97.4%; Average loss: 1.4630
# Iteration: 7793; Percent complete: 97.4%; Average loss: 1.7443
# Iteration: 7794; Percent complete: 97.4%; Average loss: 1.5645
# Iteration: 7795; Percent complete: 97.4%; Average loss: 1.4870
# Iteration: 7796; Percent complete: 97.5%; Average loss: 1.6872
# Iteration: 7797; Percent complete: 97.5%; Average loss: 1.7143
# Iteration: 7798; Percent complete: 97.5%; Average loss: 1.7689
# Iteration: 7799; Percent complete: 97.5%; Average loss: 1.5336
# Iteration: 7800; Percent complete: 97.5%; Average loss: 1.7298
# Iteration: 7801; Percent complete: 97.5%; Average loss: 1.5148
# Iteration: 7802; Percent complete: 97.5%; Average loss: 1.8337
# Iteration: 7803; Percent complete: 97.5%; Average loss: 1.6434
# Iteration: 7804; Percent complete: 97.5%; Average loss: 1.7680
# Iteration: 7805; Percent complete: 97.6%; Average loss: 1.6558
# Iteration: 7806; Percent complete: 97.6%; Average loss: 1.6682
# Iteration: 7807; Percent complete: 97.6%; Average loss: 1.4341
# Iteration: 7808; Percent complete: 97.6%; Average loss: 1.8683
# Iteration: 7809; Percent complete: 97.6%; Average loss: 1.7873
# Iteration: 7810; Percent complete: 97.6%; Average loss: 1.6373
# Iteration: 7811; Percent complete: 97.6%; Average loss: 1.5403
# Iteration: 7812; Percent complete: 97.7%; Average loss: 1.4927
# Iteration: 7813; Percent complete: 97.7%; Average loss: 1.6282
# Iteration: 7814; Percent complete: 97.7%; Average loss: 1.5841
# Iteration: 7815; Percent complete: 97.7%; Average loss: 1.7979
# Iteration: 7816; Percent complete: 97.7%; Average loss: 1.7960
# Iteration: 7817; Percent complete: 97.7%; Average loss: 1.6104
# Iteration: 7818; Percent complete: 97.7%; Average loss: 1.6764
# Iteration: 7819; Percent complete: 97.7%; Average loss: 1.7201
# Iteration: 7820; Percent complete: 97.8%; Average loss: 1.6288
# Iteration: 7821; Percent complete: 97.8%; Average loss: 1.5426
# Iteration: 7822; Percent complete: 97.8%; Average loss: 1.7790
# Iteration: 7823; Percent complete: 97.8%; Average loss: 1.7862
# Iteration: 7824; Percent complete: 97.8%; Average loss: 1.7250
# Iteration: 7825; Percent complete: 97.8%; Average loss: 1.5743
# Iteration: 7826; Percent complete: 97.8%; Average loss: 1.6415
# Iteration: 7827; Percent complete: 97.8%; Average loss: 1.8623
# Iteration: 7828; Percent complete: 97.9%; Average loss: 1.8196
# Iteration: 7829; Percent complete: 97.9%; Average loss: 1.6748
# Iteration: 7830; Percent complete: 97.9%; Average loss: 1.5843
# Iteration: 7831; Percent complete: 97.9%; Average loss: 1.7434
# Iteration: 7832; Percent complete: 97.9%; Average loss: 1.7101
# Iteration: 7833; Percent complete: 97.9%; Average loss: 1.7800
# Iteration: 7834; Percent complete: 97.9%; Average loss: 1.7998
# Iteration: 7835; Percent complete: 97.9%; Average loss: 1.8991
# Iteration: 7836; Percent complete: 98.0%; Average loss: 1.7784
# Iteration: 7837; Percent complete: 98.0%; Average loss: 1.7523
# Iteration: 7838; Percent complete: 98.0%; Average loss: 1.5928
# Iteration: 7839; Percent complete: 98.0%; Average loss: 1.5671
# Iteration: 7840; Percent complete: 98.0%; Average loss: 1.3854
# Iteration: 7841; Percent complete: 98.0%; Average loss: 1.6908
# Iteration: 7842; Percent complete: 98.0%; Average loss: 1.8539
# Iteration: 7843; Percent complete: 98.0%; Average loss: 1.6827
# Iteration: 7844; Percent complete: 98.0%; Average loss: 1.4902
# Iteration: 7845; Percent complete: 98.1%; Average loss: 1.7646
# Iteration: 7846; Percent complete: 98.1%; Average loss: 1.9165
# Iteration: 7847; Percent complete: 98.1%; Average loss: 1.8547
# Iteration: 7848; Percent complete: 98.1%; Average loss: 1.6749
# Iteration: 7849; Percent complete: 98.1%; Average loss: 1.7286
# Iteration: 7850; Percent complete: 98.1%; Average loss: 1.8293
# Iteration: 7851; Percent complete: 98.1%; Average loss: 1.8612
# Iteration: 7852; Percent complete: 98.2%; Average loss: 1.6412
# Iteration: 7853; Percent complete: 98.2%; Average loss: 2.0000
# Iteration: 7854; Percent complete: 98.2%; Average loss: 1.8074
# Iteration: 7855; Percent complete: 98.2%; Average loss: 1.7971
# Iteration: 7856; Percent complete: 98.2%; Average loss: 1.8661
# Iteration: 7857; Percent complete: 98.2%; Average loss: 1.5911
# Iteration: 7858; Percent complete: 98.2%; Average loss: 1.8317
# Iteration: 7859; Percent complete: 98.2%; Average loss: 1.8901
# Iteration: 7860; Percent complete: 98.2%; Average loss: 1.5979
# Iteration: 7861; Percent complete: 98.3%; Average loss: 1.5538
# Iteration: 7862; Percent complete: 98.3%; Average loss: 1.6765
# Iteration: 7863; Percent complete: 98.3%; Average loss: 1.6337
# Iteration: 7864; Percent complete: 98.3%; Average loss: 1.5872
# Iteration: 7865; Percent complete: 98.3%; Average loss: 1.4373
# Iteration: 7866; Percent complete: 98.3%; Average loss: 1.7538
# Iteration: 7867; Percent complete: 98.3%; Average loss: 1.4498
# Iteration: 7868; Percent complete: 98.4%; Average loss: 1.5851
# Iteration: 7869; Percent complete: 98.4%; Average loss: 1.5709
# Iteration: 7870; Percent complete: 98.4%; Average loss: 1.5560
# Iteration: 7871; Percent complete: 98.4%; Average loss: 1.5058
# Iteration: 7872; Percent complete: 98.4%; Average loss: 1.8352
# Iteration: 7873; Percent complete: 98.4%; Average loss: 1.7064
# Iteration: 7874; Percent complete: 98.4%; Average loss: 1.6214
# Iteration: 7875; Percent complete: 98.4%; Average loss: 1.6966
# Iteration: 7876; Percent complete: 98.5%; Average loss: 1.7297
# Iteration: 7877; Percent complete: 98.5%; Average loss: 1.7621
# Iteration: 7878; Percent complete: 98.5%; Average loss: 1.7199
# Iteration: 7879; Percent complete: 98.5%; Average loss: 1.6895
# Iteration: 7880; Percent complete: 98.5%; Average loss: 1.6727
# Iteration: 7881; Percent complete: 98.5%; Average loss: 1.7214
# Iteration: 7882; Percent complete: 98.5%; Average loss: 1.5165
# Iteration: 7883; Percent complete: 98.5%; Average loss: 1.6778
# Iteration: 7884; Percent complete: 98.6%; Average loss: 1.4679
# Iteration: 7885; Percent complete: 98.6%; Average loss: 1.8769
# Iteration: 7886; Percent complete: 98.6%; Average loss: 1.9147
# Iteration: 7887; Percent complete: 98.6%; Average loss: 1.5714
# Iteration: 7888; Percent complete: 98.6%; Average loss: 1.7251
# Iteration: 7889; Percent complete: 98.6%; Average loss: 1.9279
# Iteration: 7890; Percent complete: 98.6%; Average loss: 1.4871
# Iteration: 7891; Percent complete: 98.6%; Average loss: 1.8661
# Iteration: 7892; Percent complete: 98.7%; Average loss: 1.7920
# Iteration: 7893; Percent complete: 98.7%; Average loss: 1.7196
# Iteration: 7894; Percent complete: 98.7%; Average loss: 1.7021
# Iteration: 7895; Percent complete: 98.7%; Average loss: 1.7557
# Iteration: 7896; Percent complete: 98.7%; Average loss: 1.6288
# Iteration: 7897; Percent complete: 98.7%; Average loss: 1.6709
# Iteration: 7898; Percent complete: 98.7%; Average loss: 1.6973
# Iteration: 7899; Percent complete: 98.7%; Average loss: 1.7457
# Iteration: 7900; Percent complete: 98.8%; Average loss: 1.4993
# Iteration: 7901; Percent complete: 98.8%; Average loss: 1.8527
# Iteration: 7902; Percent complete: 98.8%; Average loss: 1.6083
# Iteration: 7903; Percent complete: 98.8%; Average loss: 1.7331
# Iteration: 7904; Percent complete: 98.8%; Average loss: 1.7081
# Iteration: 7905; Percent complete: 98.8%; Average loss: 1.7293
# Iteration: 7906; Percent complete: 98.8%; Average loss: 1.5501
# Iteration: 7907; Percent complete: 98.8%; Average loss: 1.5851
# Iteration: 7908; Percent complete: 98.9%; Average loss: 1.6649
# Iteration: 7909; Percent complete: 98.9%; Average loss: 1.6893
# Iteration: 7910; Percent complete: 98.9%; Average loss: 1.6593
# Iteration: 7911; Percent complete: 98.9%; Average loss: 1.8789
# Iteration: 7912; Percent complete: 98.9%; Average loss: 1.6748
# Iteration: 7913; Percent complete: 98.9%; Average loss: 1.6926
# Iteration: 7914; Percent complete: 98.9%; Average loss: 1.6903
# Iteration: 7915; Percent complete: 98.9%; Average loss: 1.4773
# Iteration: 7916; Percent complete: 99.0%; Average loss: 1.7085
# Iteration: 7917; Percent complete: 99.0%; Average loss: 1.6199
# Iteration: 7918; Percent complete: 99.0%; Average loss: 1.6742
# Iteration: 7919; Percent complete: 99.0%; Average loss: 1.6248
# Iteration: 7920; Percent complete: 99.0%; Average loss: 1.7158
# Iteration: 7921; Percent complete: 99.0%; Average loss: 1.6316
# Iteration: 7922; Percent complete: 99.0%; Average loss: 1.6207
# Iteration: 7923; Percent complete: 99.0%; Average loss: 1.5170
# Iteration: 7924; Percent complete: 99.1%; Average loss: 1.6310
# Iteration: 7925; Percent complete: 99.1%; Average loss: 1.7127
# Iteration: 7926; Percent complete: 99.1%; Average loss: 1.4732
# Iteration: 7927; Percent complete: 99.1%; Average loss: 1.8826
# Iteration: 7928; Percent complete: 99.1%; Average loss: 1.6923
# Iteration: 7929; Percent complete: 99.1%; Average loss: 1.6784
# Iteration: 7930; Percent complete: 99.1%; Average loss: 1.4785
# Iteration: 7931; Percent complete: 99.1%; Average loss: 1.7157
# Iteration: 7932; Percent complete: 99.2%; Average loss: 1.8714
# Iteration: 7933; Percent complete: 99.2%; Average loss: 1.7623
# Iteration: 7934; Percent complete: 99.2%; Average loss: 1.5533
# Iteration: 7935; Percent complete: 99.2%; Average loss: 1.6722
# Iteration: 7936; Percent complete: 99.2%; Average loss: 1.6323
# Iteration: 7937; Percent complete: 99.2%; Average loss: 1.6353
# Iteration: 7938; Percent complete: 99.2%; Average loss: 1.7507
# Iteration: 7939; Percent complete: 99.2%; Average loss: 1.7974
# Iteration: 7940; Percent complete: 99.2%; Average loss: 1.9167
# Iteration: 7941; Percent complete: 99.3%; Average loss: 1.7375
# Iteration: 7942; Percent complete: 99.3%; Average loss: 1.6074
# Iteration: 7943; Percent complete: 99.3%; Average loss: 1.8154
# Iteration: 7944; Percent complete: 99.3%; Average loss: 1.9826
# Iteration: 7945; Percent complete: 99.3%; Average loss: 1.7772
# Iteration: 7946; Percent complete: 99.3%; Average loss: 1.7866
# Iteration: 7947; Percent complete: 99.3%; Average loss: 1.6046
# Iteration: 7948; Percent complete: 99.4%; Average loss: 1.6542
# Iteration: 7949; Percent complete: 99.4%; Average loss: 1.6801
# Iteration: 7950; Percent complete: 99.4%; Average loss: 1.6313
# Iteration: 7951; Percent complete: 99.4%; Average loss: 1.8488
# Iteration: 7952; Percent complete: 99.4%; Average loss: 1.7773
# Iteration: 7953; Percent complete: 99.4%; Average loss: 1.5932
# Iteration: 7954; Percent complete: 99.4%; Average loss: 1.6463
# Iteration: 7955; Percent complete: 99.4%; Average loss: 1.6055
# Iteration: 7956; Percent complete: 99.5%; Average loss: 1.8261
# Iteration: 7957; Percent complete: 99.5%; Average loss: 1.6728
# Iteration: 7958; Percent complete: 99.5%; Average loss: 1.3614
# Iteration: 7959; Percent complete: 99.5%; Average loss: 1.7978
# Iteration: 7960; Percent complete: 99.5%; Average loss: 1.6151
# Iteration: 7961; Percent complete: 99.5%; Average loss: 1.6081
# Iteration: 7962; Percent complete: 99.5%; Average loss: 1.6174
# Iteration: 7963; Percent complete: 99.5%; Average loss: 1.7004
# Iteration: 7964; Percent complete: 99.6%; Average loss: 1.4310
# Iteration: 7965; Percent complete: 99.6%; Average loss: 1.6734
# Iteration: 7966; Percent complete: 99.6%; Average loss: 1.9269
# Iteration: 7967; Percent complete: 99.6%; Average loss: 1.7077
# Iteration: 7968; Percent complete: 99.6%; Average loss: 1.7532
# Iteration: 7969; Percent complete: 99.6%; Average loss: 1.7045
# Iteration: 7970; Percent complete: 99.6%; Average loss: 1.6629
# Iteration: 7971; Percent complete: 99.6%; Average loss: 1.5856
# Iteration: 7972; Percent complete: 99.7%; Average loss: 1.6686
# Iteration: 7973; Percent complete: 99.7%; Average loss: 1.6608
# Iteration: 7974; Percent complete: 99.7%; Average loss: 1.6001
# Iteration: 7975; Percent complete: 99.7%; Average loss: 1.6310
# Iteration: 7976; Percent complete: 99.7%; Average loss: 1.6360
# Iteration: 7977; Percent complete: 99.7%; Average loss: 1.6482
# Iteration: 7978; Percent complete: 99.7%; Average loss: 1.7992
# Iteration: 7979; Percent complete: 99.7%; Average loss: 1.6926
# Iteration: 7980; Percent complete: 99.8%; Average loss: 1.6520
# Iteration: 7981; Percent complete: 99.8%; Average loss: 1.6898
# Iteration: 7982; Percent complete: 99.8%; Average loss: 1.3730
# Iteration: 7983; Percent complete: 99.8%; Average loss: 1.6653
# Iteration: 7984; Percent complete: 99.8%; Average loss: 1.5235
# Iteration: 7985; Percent complete: 99.8%; Average loss: 1.7050
# Iteration: 7986; Percent complete: 99.8%; Average loss: 1.7110
# Iteration: 7987; Percent complete: 99.8%; Average loss: 1.5198
# Iteration: 7988; Percent complete: 99.9%; Average loss: 1.5682
# Iteration: 7989; Percent complete: 99.9%; Average loss: 1.8210
# Iteration: 7990; Percent complete: 99.9%; Average loss: 1.6359
# Iteration: 7991; Percent complete: 99.9%; Average loss: 1.7815
# Iteration: 7992; Percent complete: 99.9%; Average loss: 1.5888
# Iteration: 7993; Percent complete: 99.9%; Average loss: 1.7853
# Iteration: 7994; Percent complete: 99.9%; Average loss: 1.6202
# Iteration: 7995; Percent complete: 99.9%; Average loss: 1.7886
# Iteration: 7996; Percent complete: 100.0%; Average loss: 1.7503
# Iteration: 7997; Percent complete: 100.0%; Average loss: 1.6740
# Iteration: 7998; Percent complete: 100.0%; Average loss: 1.6224
# Iteration: 7999; Percent complete: 100.0%; Average loss: 1.6129
# Iteration: 8000; Percent complete: 100.0%; Average loss: 1.7612

# %%
# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# Bot: hi . . for you . .
# Bot: hello . is good . .
# Bot: what ? . . . .
# Bot: what is it ? is good .
# Bot: okay . . is your own idea .
# Error: Encountered unknown word.
# Bot: hello . i m coming down . .
# Bot: hi . . for you . .
# Bot: you know what i m talking about .
# Bot: i don t know . for me .
# Bot: i know . for you . !
# Bot: yes sir . is in your mouth .
# Bot: hello . is good . .
# Bot: yes . ! ! ! !
# Bot:  you u see me .
# Bot: yes . ! ! ! !
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: fine . for you . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
# Bot: hello . is good . .
